# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib inline
import tensorflow as tf
import keras.backend as K

from keras import metrics
from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout,Maximum
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose,Conv3D,Conv3DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalMaxPool2D,MaxPooling3D
from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from sklearn.utils import class_weight
from keras.callbacks import ModelCheckpoint
from keras.callbacks import CSVLogger
from keras.callbacks import EarlyStopping

import os
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from medpy.io import load
import numpy as np

#import cv2
import nibabel as nib
from PIL import Image

# %%
def conv_block(input_mat,num_filters,kernel_size,batch_norm):
    X = Conv2D(num_filters,kernel_size=(kernel_size,kernel_size),strides=(1,1),padding='same')(input_mat)
    if batch_norm:
        X = BatchNormalization()(X)
  
    X = Activation('relu')(X)

    X = Conv2D(num_filters,kernel_size=(kernel_size,kernel_size),strides=(1,1),padding='same')(X)
    if batch_norm:
        X = BatchNormalization()(X)
  
    X = Activation('relu')(X)
    return X
    


def Unet(input_img, n_filters = 16, dropout = 0.2, batch_norm = True):

    c1 = conv_block(input_img,n_filters,3,batch_norm)
    p1 = MaxPooling2D(pool_size=(2, 2), strides=2)(c1)
    p1 = Dropout(dropout)(p1)
  
    c2 = conv_block(p1,n_filters*2,3,batch_norm)
    p2 = MaxPooling2D(pool_size=(2,2) ,strides=2)(c2)
    p2 = Dropout(dropout)(p2)

    c3 = conv_block(p2,n_filters*4,3,batch_norm)
    p3 = MaxPooling2D(pool_size=(2,2) ,strides=2)(c3)
    p3 = Dropout(dropout)(p3)
  
    c4 = conv_block(p3,n_filters*8,3,batch_norm)
    p4 = MaxPooling2D(pool_size=(2,2) ,strides=2)(c4)
    p4 = Dropout(dropout)(p4)
  
    c5 = conv_block(p4,n_filters*16,3,batch_norm)

    u6 = Conv2DTranspose(n_filters*8, (3,3), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6,c4])
    c6 = conv_block(u6,n_filters*8,3,batch_norm)
    c6 = Dropout(dropout)(c6)
    u7 = Conv2DTranspose(n_filters*4,(3,3),strides = (2,2) , padding= 'same')(c6)

    u7 = concatenate([u7,c3])
    c7 = conv_block(u7,n_filters*4,3,batch_norm)
    c7 = Dropout(dropout)(c7)
    u8 = Conv2DTranspose(n_filters*2,(3,3),strides = (2,2) , padding='same')(c7)
    u8 = concatenate([u8,c2])

    c8 = conv_block(u8,n_filters*2,3,batch_norm)
    c8 = Dropout(dropout)(c8)
    u9 = Conv2DTranspose(n_filters,(3,3),strides = (2,2) , padding='same')(c8)

    u9 = concatenate([u9,c1])

    c9 = conv_block(u9,n_filters,3,batch_norm)
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)

    model = Model(inputs=input_img, outputs=outputs)

    return model

# %%
tf.test.is_gpu_available(
    cuda_only=False, min_cuda_compute_capability=None
)
# Out:
# False

# %%
def dice_coef(y_true, y_pred, epsilon=0.00001):
    """
    Dice = (2*|X & Y|)/ (|X|+ |Y|)
         =  2*sum(|A*B|)/(sum(A^2)+sum(B^2))
    ref: https://arxiv.org/pdf/1606.04797v1.pdf
    
    """
    axis = (0,1,2,3)
    dice_numerator = 2. * K.sum(y_true * y_pred, axis=axis) + epsilon
    dice_denominator = K.sum(y_true*y_true, axis=axis) + K.sum(y_pred*y_pred, axis=axis) + epsilon
    return K.mean((dice_numerator)/(dice_denominator))


def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)


def standardize(image):

    standardized_image = np.zeros(image.shape)

    #
    
        # iterate over the `z` dimension
    for z in range(image.shape[2]):
        # get a slice of the image 
        # at channel c and z-th dimension `z`
        image_slice = image[:,:,z]

        # subtract the mean from image_slice
        centered = image_slice - np.mean(image_slice)
        
        # divide by the standard deviation (only if it is different from zero)
        if(np.std(centered)!=0):
            centered = centered/np.std(centered) 

        # update  the slice of standardized image
        # with the scaled centered and scaled image
        standardized_image[:, :, z] = centered

    ### END CODE HERE ###

    return standardized_image

# %%
input_img = Input((240, 240, 1))
model = Unet(input_img,16,0.1,True)
learning_rate = 0.001
epochs = 5000
decay_rate = learning_rate / epochs
model.compile(optimizer=Adam(lr=learning_rate, decay = decay_rate), loss=dice_coef_loss, metrics=[dice_coef])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 240, 240, 1) 0
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 240, 240, 16) 160         input_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 240, 240, 16) 64          conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 240, 240, 16) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 240, 240, 16) 2320        activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 240, 240, 16) 64          conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 240, 240, 16) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 120, 120, 16) 0           activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 120, 120, 16) 0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 120, 120, 32) 4640        dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 120, 120, 32) 128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 120, 120, 32) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 120, 120, 32) 9248        activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 120, 120, 32) 128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 120, 120, 32) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 60, 60, 32)   0           activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 60, 60, 32)   0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 60, 60, 64)   18496       dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 60, 60, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 60, 60, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 60, 60, 64)   36928       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 60, 60, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 60, 60, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 30, 30, 64)   0           activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 30, 30, 64)   0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 30, 30, 128)  73856       dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 30, 30, 128)  512         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 30, 30, 128)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 30, 30, 128)  147584      activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 30, 30, 128)  512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 30, 30, 128)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 15, 15, 128)  0           activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 15, 15, 128)  0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 15, 15, 256)  295168      dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 15, 15, 256)  1024        conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 15, 15, 256)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 15, 15, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 15, 15, 256)  1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 15, 15, 256)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 30, 30, 128)  295040      activation_27[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 30, 30, 256)  0           conv2d_transpose_4[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 30, 30, 128)  295040      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 30, 30, 128)  512         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 30, 30, 128)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 30, 30, 128)  147584      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 30, 30, 128)  512         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 30, 30, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 30, 30, 128)  0           activation_29[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 60, 60, 64)   73792       dropout_11[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 60, 60, 128)  0           conv2d_transpose_5[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 60, 60, 64)   73792       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 60, 60, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 60, 60, 64)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 60, 60, 64)   36928       activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 60, 60, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 60, 60, 64)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 60, 60, 64)   0           activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 120, 120, 32) 18464       dropout_12[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 120, 120, 64) 0           conv2d_transpose_6[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 120, 120, 32) 18464       concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 120, 120, 32) 128         conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 120, 120, 32) 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 120, 120, 32) 9248        activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 120, 120, 32) 128         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 120, 120, 32) 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 120, 120, 32) 0           activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 240, 240, 16) 4624        dropout_13[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 240, 240, 32) 0           conv2d_transpose_7[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 240, 240, 16) 4624        concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 240, 240, 16) 64          conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 240, 240, 16) 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 240, 240, 16) 2320        activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 240, 240, 16) 64          conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 240, 240, 16) 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 240, 240, 1)  17          activation_35[0][0]
# ==================================================================================================
# Total params: 2,164,305
# Trainable params: 2,161,361
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
path = 'MICCAI_BraTS2020_TrainingData'
all_images = os.listdir(path)
all_images.sort()
data = np.zeros((240,240,155,4))
x_to = []
y_to = []

for i in range(len(all_images)):
    if(all_images[i] != '.DS_Store'):
        x = all_images[i]
        print(x)
        folder_path = path + '/' + x;
        print(folder_path)
    else:
        continue
    if(folder_path != '.DS_Store'):
        modalities = os.listdir(folder_path)
        modalities.sort()
        #data = []
    else:
        continue
    for j in range(len(modalities)-1):
    #print(modalities[j])
    
        image_path = folder_path + '/' + modalities[j]
        #print(image_path)
        if(image_path[-10:-1] + image_path[-1] == 'seg.nii.gz'):
            img = nib.load(image_path);
            image_data2 = img.get_data()
            image_data2 = np.asarray(image_data2)
            #print("Entered ground truth")
        if(image_path[-12:-1] + image_path[-1] == 'flair.nii.gz'):
            img = nib.load(image_path);
            image_data = img.get_data()
            image_data = np.asarray(image_data)
            image_data = standardize(image_data)
    
    #print(data.shape)
    #print(image_data2.shape)  

    
    for slice_no in range(90,110):
        a = slice_no
        X = image_data[:,:,slice_no]
        #print(a)
        Y = image_data2[:,:,slice_no]
    # imgplot = plt.imshow(X[:,:,2])
    # plt.show(block=False)
    # plt.pause(0.3)
    # plt.close()
  
    # imgplot = plt.imshow(Y)
    # plt.show(block=False)
    # plt.pause(0.3)
    # plt.close()

        if(X.any()!=0 and Y.any()!=0 and len(np.unique(Y)) == 4):
          #print(slice_no)
            x_to.append(X.reshape(240,240,1))
            y_to.append(Y.reshape(240,240,1))
x_to = np.asarray(x_to)
y_to = np.asarray(y_to)
# Out:
# BraTS20_Training_001
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_001
# /Users/egemenakbal/opt/miniconda3/envs/tfp-gpu/lib/python3.6/site-packages/ipykernel_launcher.py:34: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# /Users/egemenakbal/opt/miniconda3/envs/tfp-gpu/lib/python3.6/site-packages/ipykernel_launcher.py:29: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# BraTS20_Training_002
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_002
# BraTS20_Training_003
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_003
# BraTS20_Training_004
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_004
# BraTS20_Training_005
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_005
# BraTS20_Training_006
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_006
# BraTS20_Training_007
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_007
# BraTS20_Training_008
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_008
# BraTS20_Training_009
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_009
# BraTS20_Training_010
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_010
# BraTS20_Training_011
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_011
# BraTS20_Training_012
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_012
# BraTS20_Training_013
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_013
# BraTS20_Training_014
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_014
# BraTS20_Training_015
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_015
# BraTS20_Training_016
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_016
# BraTS20_Training_017
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_017
# BraTS20_Training_018
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_018
# BraTS20_Training_019
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_019
# BraTS20_Training_020
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_020
# BraTS20_Training_021
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_021
# BraTS20_Training_022
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_022
# BraTS20_Training_023
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_023
# BraTS20_Training_024
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_024
# BraTS20_Training_025
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_025
# BraTS20_Training_026
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_026
# BraTS20_Training_027
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_027
# BraTS20_Training_028
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_028
# BraTS20_Training_029
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_029
# BraTS20_Training_030
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_030
# BraTS20_Training_031
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_031
# BraTS20_Training_032
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_032
# BraTS20_Training_033
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_033
# BraTS20_Training_034
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_034
# BraTS20_Training_035
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_035
# BraTS20_Training_036
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_036
# BraTS20_Training_037
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_037
# BraTS20_Training_038
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_038
# BraTS20_Training_039
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_039
# BraTS20_Training_040
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_040
# BraTS20_Training_041
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_041
# BraTS20_Training_042
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_042
# BraTS20_Training_043
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_043
# BraTS20_Training_044
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_044
# BraTS20_Training_045
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_045
# BraTS20_Training_046
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_046
# BraTS20_Training_047
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_047
# BraTS20_Training_048
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_048
# BraTS20_Training_049
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_049
# BraTS20_Training_050
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_050
# BraTS20_Training_051
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_051
# BraTS20_Training_052
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_052
# BraTS20_Training_053
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_053
# BraTS20_Training_054
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_054
# BraTS20_Training_055
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_055
# BraTS20_Training_056
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_056
# BraTS20_Training_057
# MICCAI_BraTS2020_TrainingData/BraTS20_Training
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_340
# BraTS20_Training_341
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_341
# BraTS20_Training_342
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_342
# BraTS20_Training_343
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_343
# BraTS20_Training_344
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_344
# BraTS20_Training_345
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_345
# BraTS20_Training_346
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_346
# BraTS20_Training_347
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_347
# BraTS20_Training_348
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_348
# BraTS20_Training_349
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_349
# BraTS20_Training_350
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_350
# BraTS20_Training_351
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_351
# BraTS20_Training_352
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_352
# BraTS20_Training_353
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_353
# BraTS20_Training_354
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_354
# BraTS20_Training_355
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_355
# BraTS20_Training_356
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_356
# BraTS20_Training_357
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_357
# BraTS20_Training_358
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_358
# BraTS20_Training_359
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_359
# BraTS20_Training_360
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_360
# BraTS20_Training_361
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_361
# BraTS20_Training_362
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_362
# BraTS20_Training_363
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_363
# BraTS20_Training_364
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_364
# BraTS20_Training_365
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_365
# BraTS20_Training_366
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_366
# BraTS20_Training_367
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_367
# BraTS20_Training_368
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_368
# BraTS20_Training_369
# MICCAI_BraTS2020_TrainingData/BraTS20_Training_369

# %% [markdown]
# ## x_to = np.asarray(x_to).astype("float64")
# y_to = np.asarray(y_to).astype("float64")
# print(x_to.shape)
# print(y_to.shape)

# %%
x_to = np.asarray(x_to).astype("float64")
y_to = np.asarray(y_to).astype("float64")
print(x_to.shape)
print(y_to.shape)
# Out:
# (2981, 240, 240, 1)
# (2981, 240, 240, 1)

# %%
plt.imshow(x_to[80] , cmap = "gray")

# %%
plt.imshow(y_to[80], cmap = "gray")

# %%
model.fit(x=x_to, y=y_to, batch_size=20, epochs=10)
# Out:
# Epoch 1/10
# 150/150 [==============================] - 641s 4s/step - loss: 0.5299 - dice_coef: 0.4701
# Epoch 2/10
# 150/150 [==============================] - 704s 5s/step - loss: 0.4284 - dice_coef: 0.5716
# Epoch 3/10
# 150/150 [==============================] - 710s 5s/step - loss: 0.4121 - dice_coef: 0.5879
# Epoch 4/10
# 150/150 [==============================] - 705s 5s/step - loss: 0.4125 - dice_coef: 0.5875
# Epoch 5/10
# 150/150 [==============================] - 704s 5s/step - loss: 0.4037 - dice_coef: 0.5963
# Epoch 6/10
# 150/150 [==============================] - 702s 5s/step - loss: 0.4039 - dice_coef: 0.5961
# Epoch 7/10
# 150/150 [==============================] - 679s 5s/step - loss: 0.4003 - dice_coef: 0.5997
# Epoch 8/10
# 150/150 [==============================] - 683s 5s/step - loss: 0.3975 - dice_coef: 0.6025
# Epoch 9/10
# 150/150 [==============================] - 822s 5s/step - loss: 0.4031 - dice_coef: 0.5969
# Epoch 10/10
# 150/150 [==============================] - 752s 5s/step - loss: 0.3968 - dice_coef: 0.6032

# %%
x_to[0].shape
# Out:
# (240, 240, 1)

# %%
def kullanat(arg):
    plt.figure()
    plt.imshow(arg, cmap = "gray")

# %%
def predict(image):
    return model.predict(np.asarray([image]) ).reshape((240,240))
idx = 2980
img = x_to[idx]
real = y_to[idx]
print(len(x_to))
kullanat(img.reshape((240,240)))
kullanat(real.reshape((240,240)))

pred = predict(img)
kullanat(pred)
# Out:
# 2981
